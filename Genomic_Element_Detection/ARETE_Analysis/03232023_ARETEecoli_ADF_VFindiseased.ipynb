# %%
import os
import pandas as pd

# %%
VF = pd.read_csv("02072023_EcoliARETE_VFDB_filtered80_crosstab_gene_name.csv")

# %%
VF1 = VF.set_index('Isolate_Pathname')

# %%
VF1
# Out:
#                   AAA92657  AAC38364  C_RS05810  KP1_RS17240  KP1_RS17280  \
# Isolate_Pathname
# EC_0012_1H1_D            0         0          0            0            0
# EC_0012_2H1_D            0         0          0            0            0
# EC_0012_2L1_D            0         0          0            0            0
# EC_0012_3S1_D            0         0          0            0            0
# EC_0012_C1_H             0         1          0            0            0
# ...                    ...       ...        ...          ...          ...
# EC_E9DN_1_E              0         0          0            0            0
# EC_E9DN_2_E              0         0          0            0            0
# EC_E9FP_1_E              0         0          0            0            0
# EC_E9L_1_E               0         0          0            0            0
# All                     36        36         16            3           11
#
# ...

# %%
VFkps = VF1.filter(regex='kps')

# %%
VFkps2 = VFkps.loc[(VFkps!=0).any(axis=1)]

# %%
VFkps2.to_csv('03232023_VFkpsclusterisolates.csv')

# %%
VFneu = VF1.filter(regex='neu')
VFneu2 = VFneu.loc[(VFneu!=0).any(axis=1)]
VFneu2.to_csv('03232023_VFneuclusterisolates.csv')

# %%
VFclb = VF1.filter(regex='clb')
VFclb2 = VFclb.loc[(VFclb!=0).any(axis=1)]
VFclb2.to_csv('03232023_VFclbclusterisolates.csv')

# %%
VFset = VF1.filter(regex='set1A')
VFset2 = VFset.loc[(VFset!=0).any(axis=1)]
VFset2.to_csv('03232023_VFset1Aclusterisolates.csv')

# %%
VFset = VF1.filter(regex='set1B')
VFset2 = VFset.loc[(VFset!=0).any(axis=1)]
VFset2.to_csv('03232023_VFset1Bclusterisolates.csv')

# %%
VFsfa = VF1.filter(regex='sfa')
VFsfa = VFsfa.loc[(VFsfa!=0).any(axis=1)]
VFsfa.to_csv('03232023_VFsfaclusterisolates.csv')

# %%
VFCR = VF1.filter(regex='C_RS05810')
VFCR2 = VFCR.loc[(VFCR!=0).any(axis=1)]
VFCR2.to_csv('03232023_VFCRclusterisolates.csv')

# %%
VFpap = VF1.filter(regex='pap')
VFpap2 = VFpap.loc[(VFpap!=0).any(axis=1)]
VFpap2.to_csv('03232023_VFpapclusterisolates.csv')

# %%
VFhcp = VF1.filter(regex='hcp')
VFhcp2 = VFhcp.loc[(VFhcp!=0).any(axis=1)]
VFhcp2.to_csv('03232023_VFhcpclusterisolates.csv')

# %%
VFtss = VF1.filter(regex='tssJ')
VFtss2 = VFtss.loc[(VFtss!=0).any(axis=1)]
VFtss2.to_csv('03232023_VFtssclusterisolates.csv')

# %%
VFshu = VF1.filter(regex='shu')
VFshu2 = VFshu.loc[(VFshu!=0).any(axis=1)]
VFshu2.to_csv('03232023_VFshuclusterisolates.csv')

# %%
VFchu = VF1.filter(regex='chu')
VFchu2 = VFchu.loc[(VFchu!=0).any(axis=1)]
VFchu2.to_csv('03232023_VFchuclusterisolates.csv')
