# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf #https://anaconda.org/anaconda/statsmodels
import statsmodels.api as sm #https://scikit-posthocs.readthedocs.io/en/latest/installation/
import scikit_posthocs as sp
import seaborn as sns
import itertools as it
from statannotations.Annotator import Annotator
import matplotlib.pyplot as plt

# %%
mobsuiteSUM = pd.read_csv("02072023_EcoliARETE_Plasmids_Isolates_All_no_novel_mobsuite_results_SUMS_all_stats.csv")

# %%
mobsuiteSUM
# Out:
#             Genome         Source Outbreak Phylogroup  Total_Plasmids
# 0    EC_7360_2H2_D       Diseased    F7360         B1              10
# 1    EC_0731_2H1_D       Diseased    F0731          G               9
# 2    EC_0731_2S2_D       Diseased    F0731          G               9
# 3    EC_23315_H1_D       Diseased   F23315          G               9
# 4    EC_23315_S2_D       Diseased   F23315          G               9
# ..             ...            ...      ...        ...             ...
# 240    EC_E4DI_1_E  Environmental      NaN          U               0
# 241    EC_E4FP_1_E  Environmental      NaN          A               0
# 242     EC_E4L_1_E  Environmental      NaN          A               0
# 243     EC_E4P_1_E  Environmental      NaN          A               0
# 244    EC_E9FP_1_E  Environmental      NaN          A               0
#
# [245 rows x 5 columns]

# %%
pairs = []

pairs2=[('A', 'B1'), ('A','B2'), ("A","C"), ("A", "D"), ("A", "E"), ("A", "G"), ("B1","B2"), ("B1", "C"), ("B1", "D"), ("B1", "E"), ("B1", "G"), ("B2", "C"), ("B2", "D"), ("B2", "E"), ("B2", "G"), ("C", "D"), ("C", "E"), ("C", "G"), ("D", "E"), ("D", "G"), ("E", "G")]

states_subcat =['A', 'B1', 'B2', 'C', 'D', 'E', 'G']
sns.set_style(style='white') 
state_palette = "colorblind"

with sns.plotting_context('notebook', font_scale = 1.4): 
    #Create new plot 
    hue_plot_params = {'data': mobsuiteSUM, 'x': 'Phylogroup', 'y': 'Total_Plasmids', "order": states_subcat, "palette": state_palette}
    ax = sns.stripplot(x="Phylogroup", y="Total_Plasmids", data=mobsuiteSUM, size=8, order=states_subcat, palette=['grey'])
plt.xticks(rotation=45, ha="right")


# plot the mean line
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            x= "Phylogroup",
            y="Total_Plasmids",
            data=mobsuiteSUM,
            showfliers=False,
            showbox=False,
            showcaps=False,
            order=states_subcat,
            ax=ax)

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

#annotating with pairs
#annot = Annotator(ax, pairs2, **hue_plot_params)
#annot.configure(test='t-test_ind', verbose=2)
#annot.apply_test()
#annot.annotate()

plt.savefig("04032023_EcoliARETE_sumofplasmidvsphylogroup.png", dpi = 400, bbox_inches= "tight")

# %%
AMRSUM = pd.read_csv("02092023_EcoliARETE_RGI_strictperfectfiltered_crosstab_ALLSUMS_stats_nomyco.csv")

# %%
pairs = []

pairs2=[('A', 'B1'), ('A','B2'), ("A","C"), ("A", "D"), ("A", "E"), ("A", "G"), ("B1","B2"), ("B1", "C"), ("B1", "D"), ("B1", "E"), ("B1", "G"), ("B2", "C"), ("B2", "D"), ("B2", "E"), ("B2", "G"), ("C", "D"), ("C", "E"), ("C", "G"), ("D", "E"), ("D", "G"), ("E", "G")]

states_subcat =['A', 'B1', 'B2', 'C', 'D', 'E', 'G']
sns.set_style(style='white') 
state_palette = "colorblind"

with sns.plotting_context('notebook', font_scale = 1.4): 
    #Create new plot 
    hue_plot_params = {'data': AMRSUM, 'x': 'Phylogroup', 'y': 'Total_AMR', "order": states_subcat, "palette": state_palette}
    ax = sns.stripplot(x="Phylogroup", y="Total_AMR", data=AMRSUM, size=8, order=states_subcat, palette=['gray'])
plt.xticks(rotation=45, ha="right")


# plot the mean line
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            x= "Phylogroup",
            y="Total_AMR",
            data=AMRSUM,
            showfliers=False,
            showbox=False,
            showcaps=False,
            order=states_subcat,
            ax=ax)

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

#annotating with pairs
#annot = Annotator(ax, pairs2, **hue_plot_params)
#annot.configure(test='t-test_ind', verbose=2)
#annot.apply_test()
#annot.annotate()

plt.savefig("04032023_EcoliARETE_sumofAMRvsphylogroup.png", dpi = 400, bbox_inches= "tight")

# %%
VFSUM = pd.read_csv("02072023_EcoliARETE_VFDB_filtered80_crosstab_ALLSUMS_stats.csv")

# %%
pairs = []

pairs2=[('A', 'B1'), ('A','B2'), ("A","C"), ("A", "D"), ("A", "E"), ("A", "G"), ("B1","B2"), ("B1", "C"), ("B1", "D"), ("B1", "E"), ("B1", "G"), ("B2", "C"), ("B2", "D"), ("B2", "E"), ("B2", "G"), ("C", "D"), ("C", "E"), ("C", "G"), ("D", "E"), ("D", "G"), ("E", "G")]

states_subcat =['A', 'B1', 'B2', 'C', 'D', 'E', 'G']
sns.set_style(style='white') 
state_palette = "colorblind"

with sns.plotting_context('notebook', font_scale = 1.4): 
    #Create new plot 
    hue_plot_params = {'data': VFSUM, 'x': 'Phylogroup', 'y': 'Total_VF', "order": states_subcat, "palette": state_palette}
    ax = sns.stripplot(x="Phylogroup", y="Total_VF", data=VFSUM, size=8, order=states_subcat, palette=['gray'])
plt.xticks(rotation=45, ha="right")


# plot the mean line
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            x= "Phylogroup",
            y="Total_VF",
            data=VFSUM,
            showfliers=False,
            showbox=False,
            showcaps=False,
            order=states_subcat,
            ax=ax)

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

#annotating with pairs
#annot = Annotator(ax, pairs2, **hue_plot_params)
#annot.configure(test='t-test_ind', verbose=2)
#annot.apply_test()
#annot.annotate()

plt.savefig("04032023_EcoliARETE_sumofVFvsphylogroup.png", dpi = 400, bbox_inches= "tight")

# %%
BACMETSUM = pd.read_csv("02072023_EcoliARETE_BACMET_filtered80_crosstab_ALLSUMS_stats.csv")

# %%
pairs = []

pairs2=[('A', 'B1'), ('A','B2'), ("A","C"), ("A", "D"), ("A", "E"), ("A", "G"), ("B1","B2"), ("B1", "C"), ("B1", "D"), ("B1", "E"), ("B1", "G"), ("B2", "C"), ("B2", "D"), ("B2", "E"), ("B2", "G"), ("C", "D"), ("C", "E"), ("C", "G"), ("D", "E"), ("D", "G"), ("E", "G")]

states_subcat =['A', 'B1', 'B2', 'C', 'D', 'E', 'G']
sns.set_style(style='white') 
state_palette = "colorblind"

with sns.plotting_context('notebook', font_scale = 1.4): 
    #Create new plot 
    hue_plot_params = {'data': BACMETSUM, 'x': 'Phylogroup', 'y': 'Total_BACMET', "order": states_subcat, "palette": state_palette}
    ax = sns.stripplot(x="Phylogroup", y="Total_BACMET", data=BACMETSUM, size=8, order=states_subcat, palette=['gray'])
plt.xticks(rotation=45, ha="right")


# plot the mean line
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            x= "Phylogroup",
            y="Total_BACMET",
            data=BACMETSUM,
            showfliers=False,
            showbox=False,
            showcaps=False,
            order=states_subcat,
            ax=ax)

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

#annotating with pairs
#annot = Annotator(ax, pairs2, **hue_plot_params)
#annot.configure(test='t-test_ind', verbose=2)
#annot.apply_test()
#annot.annotate()

plt.savefig("04032023_EcoliARETE_sumofBACMETvsphylogroup.png", dpi = 400, bbox_inches= "tight")
