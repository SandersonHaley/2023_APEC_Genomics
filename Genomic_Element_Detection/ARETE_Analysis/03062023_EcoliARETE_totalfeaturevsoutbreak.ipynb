# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf #https://anaconda.org/anaconda/statsmodels
import statsmodels.api as sm #https://scikit-posthocs.readthedocs.io/en/latest/installation/
import scikit_posthocs as sp
import seaborn as sns
import itertools as it
from statannotations.Annotator import Annotator
import matplotlib.pyplot as plt
from itertools import combinations

# %%
mobsuiteSUM = pd.read_csv("02072023_EcoliARETE_Plasmids_Isolates_All_no_novel_mobsuite_results_SUMS_all_stats.csv")

# %%
pairs = []

states_subcat =['F0012', 'F0038', 'F0205', 'F0731', 'F23315', 'F2402', 'F2655', 'F3862', 'F4957', 'F4984', 'F6041', 'F6245', 'F7360', 'F7578', 'F8630', 'F9226', 'F9413', 'F9503', 'F9619']
pairs2 = list(combinations(states_subcat, 2))
sns.set_style(style='white') 
state_palette = "colorblind"

with sns.plotting_context('notebook', font_scale = 1.4): 
    #Create new plot 
    hue_plot_params = {'data': mobsuiteSUM, 'x': 'Outbreak', 'y': 'Total_Plasmids', "order": states_subcat, "palette": state_palette}
    ax = sns.boxplot(x="Outbreak", y="Total_Plasmids", data=mobsuiteSUM, order=states_subcat, palette=['grey'])
plt.xticks(rotation=45, ha="right")


# plot the mean line
#sns.boxplot(showmeans=True,
            #meanline=False,
            #meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            #medianprops={'visible': False},
            #whiskerprops={'visible': False},
            #zorder=10,
            #x= "Outbreak",
            #y="Total_Plasmids",
            #data=mobsuiteSUM,
            #showfliers=False,
            #showbox=False,
            #showcaps=False,
            #order=states_subcat,
            #ax=ax)

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

#annotating with pairs
#annot = Annotator(ax, pairs2, **hue_plot_params)
#annot.configure(test='t-test_ind', verbose=2)
#annot.apply_test()
#annot.annotate()

plt.savefig("04032023_EcoliARETE_sumofplasmidvsoutbreak.png", dpi = 400, bbox_inches= "tight")

# %%
AMRSUM = pd.read_csv("02092023_EcoliARETE_RGI_strictperfectfiltered_crosstab_ALLSUMS_stats_nomyco.csv")

# %%
pairs = []

states_subcat =['F0012', 'F0038', 'F0205', 'F0731', 'F23315', 'F2402', 'F2655', 'F3862', 'F4957', 'F4984', 'F6041', 'F6245', 'F7360', 'F7578', 'F8630', 'F9226', 'F9413', 'F9503', 'F9619']
pairs2 = list(combinations(states_subcat, 2))
sns.set_style(style='white') 
state_palette = "colorblind"

with sns.plotting_context('notebook', font_scale = 1.4): 
    #Create new plot 
    hue_plot_params = {'data': AMRSUM, 'x': 'Outbreak', 'y': 'Total_AMR', "order": states_subcat, "palette": state_palette}
    ax = sns.boxplot(x="Outbreak", y="Total_AMR", data=AMRSUM, order=states_subcat, palette=['gray'])
plt.xticks(rotation=45, ha="right")


# plot the mean line
#sns.boxplot(showmeans=True,
           # meanline=True,
            #meanprops={'color': 'k', 'ls': '-', 'lw': 2},
           # medianprops={'visible': False},
           # whiskerprops={'visible': False},
           # zorder=10,
            #x= "Outbreak",
            #y="Total_AMR",
            #data=AMRSUM,
           # showfliers=False,
            #showbox=False,
            #showcaps=False,
            #order=states_subcat,
            #ax=ax)

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

#annotating with pairs
#annot.configure(test='t-test_ind', verbose=2)
#annot.apply_test()
#annot.annotate()

plt.savefig("04032023_EcoliARETE_sumofAMRvsoutbreak.png", dpi = 400, bbox_inches= "tight")

# %%
VFSUM = pd.read_csv("02072023_EcoliARETE_VFDB_filtered80_crosstab_ALLSUMS_stats.csv")

# %%
pairs = []

states_subcat =['F0012', 'F0038', 'F0205', 'F0731', 'F23315', 'F2402', 'F2655', 'F3862', 'F4957', 'F4984', 'F6041', 'F6245', 'F7360', 'F7578', 'F8630', 'F9226', 'F9413', 'F9503', 'F9619']
pairs2 = list(combinations(states_subcat, 2))
sns.set_style(style='white') 
state_palette = "colorblind"

with sns.plotting_context('notebook', font_scale = 1.4): 
    #Create new plot 
    hue_plot_params = {'data': VFSUM, 'x': 'Outbreak', 'y': 'Total_VF', "order": states_subcat, "palette": state_palette}
    ax = sns.boxplot(x="Outbreak", y="Total_VF", data=VFSUM, order=states_subcat, palette=['gray'])
plt.xticks(rotation=45, ha="right")


# plot the mean line
#sns.boxplot(showmeans=True,
            #meanline=True,
            #meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            #medianprops={'visible': False},
            #whiskerprops={'visible': False},
            #zorder=10,
            #x= "Outbreak",
            #y="Total_VF",
            #data=VFSUM,
            #showfliers=False,
            #showbox=False,
            #showcaps=False,
            #order=states_subcat,
            #ax=ax)

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

#annotating with pairs
#annot = Annotator(ax, pairs2, **hue_plot_params)
#annot.configure(test='t-test_ind', verbose=2)
#annot.apply_test()
#annot.annotate()

plt.savefig("04032023_EcoliARETE_sumofVFvsoutbreak.png", dpi = 400, bbox_inches= "tight")

# %%
BACMETSUM = pd.read_csv("02072023_EcoliARETE_BACMET_filtered80_crosstab_ALLSUMS_stats.csv")

# %%
pairs = []

states_subcat =['F0012', 'F0038', 'F0205', 'F0731', 'F23315', 'F2402', 'F2655', 'F3862', 'F4957', 'F4984', 'F6041', 'F6245', 'F7360', 'F7578', 'F8630', 'F9226', 'F9413', 'F9503', 'F9619']
pairs2 = list(combinations(states_subcat, 2))
sns.set_style(style='white') 
state_palette = "colorblind"

with sns.plotting_context('notebook', font_scale = 1.4): 
    #Create new plot 
    hue_plot_params = {'data': BACMETSUM, 'x': 'Outbreak', 'y': 'Total_BACMET', "order": states_subcat, "palette": state_palette}
    ax = sns.boxplot(x="Outbreak", y="Total_BACMET", data=BACMETSUM, order=states_subcat, palette=['gray'])
plt.xticks(rotation=45, ha="right")


# plot the mean line
#sns.boxplot(showmeans=True,
 #           meanline=True,
  #          meanprops={'color': 'k', 'ls': '-', 'lw': 2},
   #         medianprops={'visible': False},
    #        whiskerprops={'visible': False},
     #       zorder=10,
      #      x= "Outbreak",
       #     y="Total_BACMET",
        #    data=BACMETSUM,
         #   showfliers=False,
          #  showbox=False,
           # showcaps=False,
            #order=states_subcat,
            #ax=ax)

handles, labels = ax.get_legend_handles_labels()
l = plt.legend(handles[0:3], labels[0:3], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

#annotating with pairs
#annot = Annotator(ax, pairs2, **hue_plot_params)
#annot.configure(test='t-test_ind', verbose=2)
#annot.apply_test()
#annot.annotate()

plt.savefig("04032023_EcoliARETE_sumofBACMETvsoutbreak.png", dpi = 400, bbox_inches= "tight")
